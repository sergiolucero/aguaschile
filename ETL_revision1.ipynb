# %% [markdown]
# ## Revision #1 ETL

# %%
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.0f' % x)  # evitando notacion científica
aguas = pd.read_parquet('DATA/aguas_publish.pq')
aguas = aguas[aguas.columns[3:]]   # elimina datos irrelevantes para este análisis
aguas.describe(percentiles=[.5,.75,.9,.99,.999]).round(0)   # la cola entre el percentil 99 y el máximo ya es fuerte
# Out:
#         Enero  Febrero   Marzo   Abril    Mayo   Junio   Julio  Agosto  \
# count  119843   119559  119525  119910  120671  120664  120604  120558
# mean      520      464     458     510     641     721     696     655
# std     31106    30881   30970   31154   31304   32641   31466   31280
# min         0        0       0       0       0       0       0    -577
# 50%         2        2       2       2       2       2       2       2
# 75%        15       15      15      15      17      17      17      17
# 90%        75       70      70      78      89      95      95      93
# 99%      3500     2973    2650    3200    5370    6271    6100    5500
# 99.9%   68124    55849   50000   60182   90821  100000  100000   95057
# max   7904490  7904490 7904490 7904490 7904490 7904490 7904490 7904490
#
#        Septiembre  Octubre  ...  UTM Norte Captación (m)  \
# count      120545   120396  ...                   123805
# mean          621      627  ...                 15810712
# ...

# %% [markdown]
# Siguen apareciendo caudales desproporcionadamente altos (8 MM??). Revisemos.

# %%
mayores = aguas.sort_values('Enero', ascending=False).head(10)
mayores['Enero']
# Out:
# 3975     7904490
# 114632   6341958
# 40107    1158500
# 9726     1090000
# 77380    1035000
# 5102     1035000
# 116369    850000
# 116794    848400
# 5101      677000
# 77379     677000
# Name: Enero, dtype: float64

# %%
aguas.loc[3975]   # la ficha completa del caso en cuestión
# Out:
# Región                                                                                                Maule
# Provincia                                                                                           Linares
# Comuna                                                                                              Linares
# Nombre Solicitante                                                                             COPIHUE SPA.
# Unidad de Resolución/ Oficio/ C.B.R.                                                     1° J. de L. Curico
# Fecha de Resolución/ Envío al Juez/ Inscripción C.B.R.                                  2018-04-11 00:00:00
# N° Resolución/ Oficio/ Fojas | N° CBR                                                           C-1651-2017
# Fecha Toma Razón                                                                                       None
# Artículo Transitorio                                                                                   None
# ...
